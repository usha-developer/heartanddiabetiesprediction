# %%
import pickle
import pandas as pd
from sklearn.preprocessing import Imputer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import sklearn
import numpy as np

#reading the pickle file
m1="heart.pickle"
m2="diabetes.pickle"

#OPENING TGHE PICKLE FILE
s1=pickle.load(open(m1,"rb"))
s2=pickle.load(open(m2,"rb"))

#calcualte the bmi
from IPython.display import Image
Image("bmi.jpg",width=1000)
def BMI(height, weight): 
    bmi = weight/(height**2) 
    return bmi 
height=int(input("enter your height is in meters")) 
weight=int(input("enter your weight is in Kg")) 
  
bmi = BMI(height, weight)
print("----------------------------------")
print("your BMI result")
print("***********************************")
print("The BMI is", format(bmi), "so ", end='') 
  
# Conditions to find out BMI category 
if (bmi < 18.5): 
    print("underweight") 
  
elif ( bmi >= 18.5 and bmi < 24.9): 
    print("Healthy") 
  
elif ( bmi >= 24.9 and bmi < 30): 
    print("overweight") 
  
elif ( bmi >=30): 
    print("Suffering from Obesity") 
    
    
print("-----------------------------------")
print("predicition of diabetes")
print("***********************************")
#for diabetes
from IPython.display import Image
Image("diabetes.jpg",width=1000)

a1=int(input("enter the Glucose level"))
a2=float(input("enter the BloodPressure"))
a3=float(input("enter the SkinThickness"))
a4=float(input("enter the Insulin level"))
a5=float(input("enter the BMI"))
a6=float(input("enter the DiabetesPedigreeFunction"))
a7=int(input("enter the Age"))


result=s2.predict([[a1,a2,a3,a4,a5,a6,a7]])
if result[0]==1:
      print("********************************************")
      print("positive")
      print("********************************************")
elif result[0]==0:
      print("********************************************")
      print("neagtive")
      print("********************************************")
else:
      pass

print("-------------------------------------------")
print("prediction of heart diseases")
print("********************************************")
#for heart dieases
b1=int(input("enter the sex"))
b2=int(input("enter the age"))
b3=int(input("enter the currentSmoker"))
b4=int(input("enter the cigsPerDay"))
b5=float(input("enter the prevalentStroke"))
b6=float(input("enter the prevalentHyp"))
b7=int(input("enter the diabetes"))
b8=float(input("enter the totChol"))
b9=float(input("enter the diaBP"))
b10=float(input("enter the sysBP"))
b11=int(input("enter the heartRate"))
b12=float(input("enter the glucose"))
result2=s1.predict([[b1,b2,b3,b4,b5,b6,b7,b8,b9,b10,b11,b12]])
if result2[0]==1:
      print("********************************************")
      print("positive")
      print("********************************************")
elif result2[0]==0:
      print("********************************************")
      print("neagtive")
      print("********************************************")
else:
      pass
# Out:
# enter your height is in meters56
# enter your weight is in Kg67
# ----------------------------------
# your BMI result
# ***********************************
# The BMI is 0.021364795918367346 so underweight
# -----------------------------------
# predicition of diabetes
# ***********************************
# enter the Glucose level654
# enter the BloodPressure234
# enter the SkinThickness098
# enter the Insulin level87
# enter the BMI45
# enter the DiabetesPedigreeFunction23
# enter the Age67
# ********************************************
# positive
# ********************************************
# -------------------------------------------
# prediction of heart diseases
# ********************************************
# enter the sex76
# enter the age45
# enter the currentSmoker1
# enter the cigsPerDay45
# enter the prevalentStroke98
# enter the prevalentHyp78
# enter the diabetes23
# enter the totChol54
# enter the diaBP98
# enter the sysBP78
# enter the heartRate99
# ...
